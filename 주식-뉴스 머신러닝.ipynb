# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df= pd.read_csv("./전처리/df_stock.csv")
df_stock = df.drop(['Unnamed: 0','Code'],axis = 1)

# 1월3일의 결과를 1월 2일의 기사를 토대로 예측해야 하므로 한칸 위로
df_stock['target']=df_stock['ChangeCode'].shift(-1)
# shift가 발생하면서 1월2일의 라벨들이 12월 30이롤 이동하기 때문에 삭제
check = (df_stock['Date'] == '2019-12-30')
# ~ 기호를 이용하여, 해당하지 않은 데이터만 남긴다
df_stock = df_stock[~check]

# 라벨인코딩을 통해서, 해당 타겟 값을 바꿔준다.
encoder = LabelEncoder()
encoder.fit(df_stock['target'])
labels = encoder.transform(df_stock['target'])
df_stock['target'] = labels

# %%
from pycaret.classification import *

# main - feature 500

df_news = pd.read_csv('./전처리/TF-IDF/main_tf-idf_500.csv')

# 주식 데이터와 뉴스 데이터를 맞추기 위해서,
# 회사의 이름과 날짜를 하나의 id(키) 역할로 만듬
df_stock['Date'] = df_stock['Date'].str.replace('-','.')
df_stock['id'] = df_stock['Name']+df_stock['Date']
df_news['id'] = df_news['Company']+df_news['Day']

total_df = pd.merge(df_stock, df_news, on = 'id').drop(['Name','Date','id','Company','Day','Unnamed: 0','ChangeCode'],axis=1)
total_df = total_df.dropna()

setup_clf = setup(data=total_df, target='target', session_id = 1, use_gpu = True)
top5_main_500 = compare_models(sort='Accuracy', n_select=5, exclude=['catboost','gbc']) # 해당 모델들이 시간이 너무 걸려서 그냥 빼버림 ㅠㅠ
# Out:
# <style  type="text/css" >
#     #T_02a49_ th {
#           text-align: left;
#     }#T_02a49_row0_col0,#T_02a49_row0_col3,#T_02a49_row0_col5,#T_02a49_row1_col0,#T_02a49_row1_col1,#T_02a49_row1_col2,#T_02a49_row1_col3,#T_02a49_row1_col4,#T_02a49_row1_col5,#T_02a49_row1_col6,#T_02a49_row1_col7,#T_02a49_row2_col0,#T_02a49_row2_col1,#T_02a49_row2_col2,#T_02a49_row2_col3,#T_02a49_row2_col4,#T_02a49_row2_col5,#T_02a49_row2_col6,#T_02a49_row2_col7,#T_02a49_row3_col0,#T_02a49_row3_col1,#T_02a49_row3_col2,#T_02a49_row3_col3,#T_02a49_row3_col4,#T_02a49_row3_col5,#T_02a49_row3_col6,#T_02a49_row3_col7,#T_02a49_row4_col0,#T_02a49_row4_col1,#T_02a49_row4_col2,#T_02a49_row4_col3,#T_02a49_row4_col4,#T_02a49_row4_col5,#T_02a49_row4_col6,#T_02a49_row4_col7,#T_02a49_row5_col0,#T_02a49_row5_col1,#T_02a49_row5_col2,#T_02a49_row5_col3,#T_02a49_row5_col4,#T_02a49_row5_col5,#T_02a49_row5_col6,#T_02a49_row5_col7,#T_02a49_row6_col0,#T_02a49_row6_col1,#T_02a49_row6_col2,#T_02a49_row6_col3,#T_02a49_row6_col4,#T_02a49_row6_col5,#T_02a49_row6_col6,#T_02a49_row6_col7,#T_02a49_row7_col0,#T_02a49_row7_col1,#T_02a49_row7_col2,#T_02a49_row7_col4,#T_02a49_row7_col6,#T_02a49_row7_col7,#T_02a49_row8_col0,#T_02a49_row8_col1,#T_02a49_row8_col2,#T_02a49_row8_col3,#T_02a49_row8_col4,#T_02a49_row8_col5,#T_02a49_row8_col6,#T_02a49_row8_col7,#T_02a49_row9_col0,#T_02a49_row9_col1,#T_02a49_row9_col2,#T_02a49_row9_col3,#T_02a49_row9_col4,#T_02a49_row9_col5,#T_02a49_row9_col6,#T_02a49_row9_col7,#T_02a49_row10_col0,#T_02a49_row10_col1,#T_02a49_row10_col2,#T_02a49_row10_col3,#T_02a49_row10_col4,#T_02a49_row10_col5,#T_02a49_row10_col6,#T_02a49_row10_col7,#T_02a49_row11_col0,#T_02a49_row11_col1,#T_02a49_row11_col2,#T_02a49_row11_col3,#T_02a49_row11_col4,#T_02a49_row11_col5,#T_02a49_row11_col6,#T_02a49_row11_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_02a49_row0_col1,#T_02a49_row0_col2,#T_02a49_row0_col4,#T_02a49_row0_col6,#T_02a49_row0_col7,#T_02a49_row7_col3,#T_02a49_row7_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_02a49_row0_col8,#T_02a49_row1_col8,#T_02a49_row2_col8,#T_02a49_row4_col8,#T_02a49_row5_col8,#T_02a49_row6_col8,#T_02a49_row7_col8,#T_02a49_row8_col8,#T_02a49_row9_col8,#T_02a49_row10_col8,#T_02a49_row11_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_02a49_row3_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_02a49_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_02a49_level0_row0" class="row_heading level0 row0" >qda</th>
#                         <td id="T_02a49_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#                         <td id="T_02a49_row0_col1" class="data row0 col1" >0.5437</td>
#                         <td id="T_02a49_row0_col2" class="data row0 col2" >0.5498</td>
#                         <td id="T_02a49_row0_col3" class="data row0 col3" >0.6433</td>
#                         <td id="T_02a49_row0_col4" class="data row0 col4" >0.5573</td>
#                         <td id="T_02a49_row0_col5" class="data row0 col5" >0.5971</td>
#                         <td id="T_02a49_row0_col6" class="data row0 col6" >0.0773</td>
#                         <td id="T_02a49_row0_col7" class="data row0 col7" >0.0784</td>
#                         <td id="T_02a49_row0_col8" class="data row0 col8" >1.0340</td>
#             </tr>
#             <tr>
#                         <th id="T_02a49_level0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_02a49_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#                         <td id="T_02a49_row1_col1" class="data row1 col1" >0.5312</td>
#                         <td id="T_02a49_row1_col2" class="data row1 col2" >0.5301</td>
#                         <td id="T_02a49_row1_col3" class="data row1 col3" >0.6454</td>
#                         <td id="T_02a49_row1_col4" class="data row1 col4" >0.5458</td>
#                         <td id="T_02a49_row1_col5" class="data row1 col5" >0.5914</td>
#                         <td id="T_02a49_row1_col6" class="data row1 col6" >0.0505</td>
#                         <td id="T_02a49_row1_col7" class="data row1 col7" >0.0515</td>
#                         <td id="T_02a49_row1_col8" class="data row1 col8" >3.2750</td>
#             </tr>
#             <tr>
#                         <th id="T_02a49_level0_row2" class="row_heading level0 row2" >lr</th>
#                         <td id="T_02a49_row2_col0" class="data row2 col0" >Logistic Regression</td>
#                         <td id="T_02a49_row2_col1" class="data row2 col1" >0.5299</td>
#                         <td id="T_02a49_row2_col2" class="data row2 col2" >0.5271</td>
#                         <td id="T_02a49_row2_col3" class="data row2 col3" >0.6876</td>
#                         <td id="T_02a49_row2_col4" class="data row2 col4" >0.5418</td>
#                         <td id="T_02a49_row2_col5" class="data row2 col5" >0.6060</td>
#                         <td id="T_02a49_row2_col6" class="data row2 col6" >0.0433</td>
#                         <td id="T_02a49_row2_col7" class="data row2 col7" >0.0452</td>
#                         <td id="T_02a49_row2_col8" class="data row2 col8" >0.5760</td>
#             </tr>
#             <tr>
#                         <th id="T_02a49_level0_row3" class="row_heading level0 row3" >ridge</th>
#                         <td id="T_02a49_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#                         <td id="T_02a49_row3_col1" class="data row3 col1" >0.5275</td>
#                         <td id="T_02a49_row3_col2" class="data row3 col2" >0.0000</td>
#                         <td id="T_02a49_row3_col3" class="data row3 col3" >0.6581</td>
#                         <td id="T_02a49_row3_col4" class="data row3 col4" >0.5417</td>
#                         <td id="T_02a49_row3_col5" class="data row3 col5" >0.5942</td>
#                         <td id="T_02a49_row3_col6" class="data row3 col6" >0.0413</td>
#                         <td id="T_02a49_row3_col7" class="data row3 col7" >0.0425</td>
#                         <td id="T_02a49_row3_col8" class="data row3 col8" >0.1050</td>
#             </tr>
#             <tr>
#                         <th id="T_02a49_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#                         <td id="T_02a49_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_02a49_row4_col1" class="data row4 col1" >0.5260</td>
#                         <td id="T_02a49_row4_col2" class="data row4 col2" >0.5262</td>
#                         <td id="T_02a49_row4_col3" class="data row4 col3" >0.6375</td>
#                         <td id="T_02a49_row4_col4" class="data row4 col4" >0.5418</td>
#                         <td id="T_02a49_row4_col5" class="data row4 col5" >0.5857</td>
#                         <td id="T_02a49_row4_col6" class="data row4 col6" >0.0402</td>
#                         <td id="T_02a49_row4_col7" class="data row4 col7" >0.0410</td>
#                         <td id="T_02a49_row4_col8" class="data row4 col8" >1.6050</td>
#             </tr>
#             <tr>
#                         <th id="T_02a49_level0_row5" class="row_heading level0 row5" >lda</th>

# %%
# head - feature 500
df_news = pd.read_csv('./전처리/TF-IDF/head_tf-idf_500.csv')
df_stock['Date'] = df_stock['Date'].str.replace('-','.')
df_stock['id'] = df_stock['Name']+df_stock['Date']
df_news['id'] = df_news['Company']+df_news['Day']
total_df = pd.merge(df_stock, df_news, on = 'id').drop(['Name','Date','id','Company','Day','Unnamed: 0','ChangeCode'],axis=1)
total_df = total_df.dropna()
target = total_df['target']
test = total_df.drop(['target'], axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(test, target, test_size=0.3, shuffle=False, random_state=100)

lr_clf = LogisticRegression()
lr_clf.fit(X_train, y_train)
pred = lr_clf.predict(X_test)

# %%
print(pd.DataFrame(pred).value_counts())

print(y_test.value_counts())
# Out:
# 1    4449
# 0    2185
# dtype: int64
# 1    3484
# 0    3150
# Name: target, dtype: int64

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score

print("오차 행렬\n", confusion_matrix(y_test, pred))
print("정확도 : ", accuracy_score(y_test, pred))
print("정밀도 : ", precision_score(y_test, pred))
print("재현율 : ", recall_score(y_test, pred))
print("f1 : ", f1_score(y_test,pred))
print("roc : ", roc_auc_score(y_test,pred))
# Out:
# 오차 행렬
#  [[1108 2042]
#  [1077 2407]]
# 정확도 :  0.5298462466083811
# 정밀도 :  0.5410204540346145
# 재현율 :  0.6908725602755453
# f1 :  0.6068322198411698
# roc :  0.5213092960107885

# %%
import eli5
from eli5.sklearn  import PermutationImportance

perm_lr = PermutationImportance(lr_clf, scoring = "f1", random_state = 42).fit(X_test, y_test)
eli5.show_weights(perm_lr, top = 100, feature_names = X_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0053
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 마감
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 코스피
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0015
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 거래일
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0032
#
#                     &plusmn; 0.0022
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 순매도
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0032
#
#                     &plusmn; 0.0044
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 시황
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0030
#
#                     &plusmn; 0.0016
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 출발
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0024
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 매수
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0023
#
#                     &plusmn; 0.0013
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 쇼크
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 미래
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 증시
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0021
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 오전
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 하락
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#                     &plusmn; 0.0027
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 신한
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0028
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 업종
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 거래
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0022
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 외국인
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0019
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 프리미엄
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0018
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 예상
